# %%
dictionary = {'turkiye' : 'ankara','usa' : 'vegas'}
print(dictionary.keys())
print(dictionary.values()) #dictionaries has keys and values you can change dynamicaly

# Keys have to be immutable objects like string, boolean, float, integer or tubles
# List is not immutable
# Keys are unique
dictionary['turkiye'] = "istanbul"    # update existing entry
print(dictionary)
dictionary['yunanistan'] = "atina"       # Add new entry
print(dictionary)
del dictionary['turkiye']              # remove entry with key 'spain'
print(dictionary)
print('france' in dictionary)        # check include or not
dictionary.clear()                   # remove all entries in dict
print(dictionary)
# Out:
# dict_keys(['turkiye', 'usa'])
# dict_values(['ankara', 'vegas'])
# {'turkiye': 'istanbul', 'usa': 'vegas'}
# {'turkiye': 'istanbul', 'usa': 'vegas', 'yunanistan': 'atina'}
# {'usa': 'vegas', 'yunanistan': 'atina'}
# False
# {}

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool
from subprocess import check_output

data = pd.read_csv(r'C:\Users\COMPUTER5\Desktop\İntroML\Data\pokemon.csv') # kaggle pokemon dataset
data.head()

series = data['sp_defense']        # ı dont know but every header of pokemon dataset has "sp_" on head of header
print(type(series))
data_frame = data[['sp_defense']]  # data[['Defense']] = data frame
print(type(data_frame))
print(3>2)
true = False
print(true)

# 1 - Filtering Pandas data frame
x = data['sp_defense']>150     # There are 6 pokemon has 150 or higher value of defense power
data[x]

data[np.logical_and(data['sp_defense']>100, data['sp_attack']>100 )]# this work exactly like and operator if both conditons are true than it will work
data[np.logical_or(data['sp_defense']>100, data['sp_attack']>100 )]# or operator 
data[(data['sp_defense']>50) & (data['sp_attack']>100)] #another version of and operator on data filtering


#--------------while and for loops-------------


#Stay in loop if condition( i is not equal 5) is true
lis = [1,2,3,4,5]
for i in lis:
    print('i is: ',i)
print('')
for i, v, in enumerate(lis):#enumerate counts given thing and creates value and index from it index can be start every number we give
    print(i," : ",v,)
print(lis)
print(list(enumerate(lis)))

# For dictionaries
# We can use for loop to achive key and value of dictionary. We learnt key and value at dictionary part.
dictionary = {'england':'london','france':'paris'}
for ky,value in dictionary.items():
    print(ky," : ",value)
print('')
for value in dictionary.values(): # we didnt take key on dictionary so key value is default
    print(key," : ",value)
print('')
# For pandas we can achieve index and value
for index,value in data[['sp_attack']][0:1].iterrows():
    print(index," : ",value)
    
data[['sp_attack']][0:5].iterrows()
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# True
# False
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# i is:  5
#
# 0  :  1
# 1  :  2
# 2  :  3
# 3  :  4
# 4  :  5
# [1, 2, 3, 4, 5]
# [(0, 1), (1, 2), (2, 3), (3, 4), (4, 5)]
# england  :  london
# france  :  paris
#
# france  :  london
# france  :  paris
#
# 0  :  sp_attack    65
# Name: 0, dtype: int64
# <generator object DataFrame.iterrows at 0x0000022095704DD0>

# %%
#Data Science Toolbox Part
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool
from subprocess import check_output


def tuple_ex():
    """ return defined t tuple"""
    t = (1,2,3)
    return t
a,b,c = tuple_ex() # tuples usiing for store multiple variable in single variable
print(a,b,c)
print(a)
print(type(tuple_ex()))

# guess prints what
x = 2
def f():
    x = 3
    return x
print(x)      # x = 2 global scope
print(f())


def fc():
    y=20
    return x*y #local define of x apsend so it uses global define
print(fc())


import builtins
dir(builtins)
def square():
    """ square finding """
    
    def add():
        """ adding """
        x = 2
        y = 3
        return x+y
    return add()**2

print(square())
# default arguments
def f(a, b = 1, c = 2):
    y = a + b + c
    return y
print(f(5))
# what if we want to change default arguments
print(f(5,4,3))

def flex_Args(*flex):
    for i in flex:
        print(i)

f(2)

def dic_values(**dicval):
    for ind,val in dicval.items():
        print(ind,"-",val)
        
        
dic_values(country = "turkiye", capital = "ankara", pupulation = 5) # function values canbe dictionaryt default and flex 
# lambda function
square = lambda x: x**2     # where x is name of argument
print(square(4))
tot = lambda x,y,z: x+y+z   # where x,y,z are names of arguments
print(tot(1,2,3)) #we can define functiions easly

number_list = [1,2,3]
y = map(lambda x:x**2,number_list)#first function takes number lists and gives ssquares of values
print(list(y))

# iteration example
name = "ronaldo"
it = iter(name) #iter makes ronalda iterative strring an puts value on it next prints first iteration of ronaldo
print(next(it))    # print next iteration
print(*it)#it gives what left for iteration 

# zip example
list1 = [1,2,3,4]
list2 = [5,6,7,8]
z = zip(list1,list2)
print(z)
z_list = list(z)
print(z_list)


un_zip = zip(*z_list)
un_list1,un_list2 = list(un_zip) # unzip returns tuple
print(un_list1)
print(un_list2)
print(type(un_list2))


# Example of list comprehension
num1 = [1,2,3]
num2 = [i + 1 for i in num1 ] # list compareted with i+1 part and for makes it for all of them
print(num2)

# Conditionals on iterable
num1 = [5,10,15]
num2 = [i**2 if i == 10 else i-5 if i < 7 else i+5 for i in num1]
print(num2)
print(num1)

# lets return pokemon csv and make one more list comprehension example
# lets classify pokemons whether they have high or low speed. Our threshold is average speed.
threshold = sum(data.Speed)/len(data.Speed)
data["speed_level"] = ["high" if i > threshold else "low" for i in data.Speed]#greater threshold values tagged with high
data.loc[:10,["speed_level","Speed"]] # we will learn loc more detailed later
#week 2 is done !!!!!!!!!!!!!!
# Out:
# 1 2 3
# 1
# <class 'tuple'>
# 2
# 3
# 40
# 25
# 8
# 12
# country - turkiye
# capital - ankara
# pupulation - 5
# 16
# 6
# [1, 4, 9]
# r
# o n a l d o
# ...
# [(1, 5), (2, 6), (3, 7), (4, 8)]
# (1, 2, 3, 4)
# (5, 6, 7, 8)
# <class 'tuple'>
